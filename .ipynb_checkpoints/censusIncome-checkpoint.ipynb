# %% [markdown]
# # Import necessary dependencies

# %%
import pandas as pd
from IPython.display import display

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import numpy as np
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Load raw data

# %%
raw_data = pd.read_csv('./census-income.data', sep=',',
# names = ['age', 'class of worker', 'detailed industry recode', 'detailed occupation recode', 'education', 'wage per hour', 'enroll in edu inst last wk', 'marital stat', 'major industry code', 'major occupation code', 'race', 'hispanic origin', 'sex', 'member', 'reason for unemployment', 'full or part time employment stat', 'capital gains', 'capital losses', 'dividends from stocks', 'tax filer stat', 'region of previous residence', 'state of previous residence', 'detailed household and family stat', 'detailed household summary in household', 'instance weight', 'migration code-change in msa', 'migration code-change in reg', 'migration code-move within reg', 'live in this house 1 year ago', 'migration prev res in sunbelt', 'num persons worked for employer', 'family members under 18', 'country of birth father', 'country of birth mother', 'country of birth self', 'citizenship', 'own business or self employed', 'fill inc questionnaire for veterans admin', 'veterans benefits', 'weeks worked in year', 'year'])
names = ['age', 'class of worker', 'detailed industry recode', 'detailed occupation recode', 'education', 'wage per hour', 'enroll in edu inst last wk', 'marital stat', 'major industry code', 'major occupation code', 'race', 'hispanic origin', 'sex', 'member', 'reason for unemployment', 'full or part time employment stat', 'capital gains', 'capital losses', 'dividends from stocks', 'tax filer stat', 'region of previous residence', 'state of previous residence', 'detailed household and family stat', 'detailed household summary in household', 'instance weight', 'migration code-change in msa', 'migration code-change in reg', 'migration code-move within reg', 'live in this house 1 year ago', 'migration prev res in sunbelt', 'num persons worked for employer', 'family members under 18', 'country of birth father', 'country of birth mother', 'country of birth self', 'citizenship', 'own business or self employed', 'fill inc questionnaire for veterans admin', 'veterans benefits', 'weeks worked in year', 'year'])

# %% [markdown]
# # Show raw data

# %%
raw_data.head()
# Out:
#                                 age  class of worker  \
# 73                  Not in universe                0
# 58   Self-employed-not incorporated                4
# 18                  Not in universe                0
# 9                   Not in universe                0
# 10                  Not in universe                0
#
#     detailed industry recode   detailed occupation recode  education  \
# 73                         0         High school graduate          0
# 58                        34   Some college but no degree          0
# 18                         0                   10th grade          0
# 9                          0                     Children          0
# 10                         0                     Children          0
#
#        wage per hour enroll in edu inst last wk                  marital stat  \
# 73   Not in universe                    Widowed   Not in universe or children
# 58   Not in universe                   Divorced                  Construction
# 18       High school              Never married   Not in universe or children
# 9    Not in universe              Never married   Not in universe or children
# 10   Not in universe              Never married   Not in universe or children
#
#                      major industry code       major occupation code  ...  \
# 73                       Not in universe                       White  ...
# 58   Precision production craft & repair                       White  ...
# 18                       Not in universe   Asian or Pacific Islander  ...
# 9                        Not in universe                       White  ...
# 10                       Not in universe                       White  ...
#
#    family members under 18 country of birth father country of birth mother  \
# 73           United-States           United-States           United-States
# 58           United-States           United-States           United-States
# 18                 Vietnam                 Vietnam                 Vietnam
# 9            United-States           United-States           United-States
# 10           United-States           United-States           United-States
#
#                    country of birth self citizenship  \
# 73     Native- Born in the United States           0
# 58     Native- Born in the United States           0
# 18   Foreign born- Not a citizen of U S            0
# 9      Native- Born in the United States           0
# 10     Native- Born in the United States           0
#
#     own business or self employed  fill inc questionnaire for veterans admin  \
# 73                Not in universe                                          2
# 58                Not in universe                                          2
# 18                Not in universe                                          2
# 9                 Not in universe                                          0
# 10                Not in universe                                          0
#
#     veterans benefits weeks worked in year       year
# 73                  0                   95   - 50000.
# 58                 52                   94   - 50000.
# 18                  0                   95   - 50000.
# 9                   0                   94   - 50000.
# 10                  0                   94   - 50000.
#
# [5 rows x 41 columns]
